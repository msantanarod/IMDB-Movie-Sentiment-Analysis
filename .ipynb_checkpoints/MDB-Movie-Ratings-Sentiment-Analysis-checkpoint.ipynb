# %% [markdown]
# # IMDB-Movie-Ratings-Sentiment-Analysis

# %% [markdown]
# ## Importing libraries

# %%
# pandas & numpy:
import numpy as np
import pandas as pd

# Visualization libraries:
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# Text data cleaning:
import re
import nltk
import string
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords

# Gensim:
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from gensim import corpora

# Sentiment
from textblob import TextBlob

# %% [markdown]
# ## Know your data

# %%
df=pd.read_csv("Data/movie.csv")
df
# Out:
#                                                     text  label
# 0      I grew up (b. 1965) watching and loving the Th...      0
# 1      When I put this movie in my DVD player, and sa...      0
# 2      Why do people who do not know what a particula...      0
# 3      Even though I have great interest in Biblical ...      0
# 4      Im a die hard Dads Army fan and nothing will e...      1
# ...                                                  ...    ...
# 39995  "Western Union" is something of a forgotten cl...      1
# 39996  This movie is an incredible piece of work. It ...      1
# 39997  My wife and I watched this movie because we pl...      0
# 39998  When I first watched Flatliners, I was amazed....      1
# 39999  Why would this film be so good, but only gross...      1
#
# [40000 rows x 2 columns]

# %%
# Rename 'text' column:

df.rename(columns={"text": "review"},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   review  40000 non-null  object
#  1   label   40000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 625.1+ KB

# %%
# Number of positives and negative reviews:

df['label'].value_counts()
# Out:
# 0    20019
# 1    19981
# Name: label, dtype: int64

# %%
# Percentage of positive and negative reviews:

df['label'].value_counts()/len(df)
# Out:
# 0    0.500475
# 1    0.499525
# Name: label, dtype: float64

# %%
# What are the longest and shortest review?:

df['review_length']=df.review.str.len()

# %%
df
# Out:
#                                                   review  label  review_length
# 0      I grew up (b. 1965) watching and loving the Th...      0            874
# 1      When I put this movie in my DVD player, and sa...      0           1811
# 2      Why do people who do not know what a particula...      0            983
# 3      Even though I have great interest in Biblical ...      0            351
# 4      Im a die hard Dads Army fan and nothing will e...      1            983
# ...                                                  ...    ...            ...
# 39995  "Western Union" is something of a forgotten cl...      1           3111
# 39996  This movie is an incredible piece of work. It ...      1            291
# 39997  My wife and I watched this movie because we pl...      0           1092
# 39998  When I first watched Flatliners, I was amazed....      1           1045
# 39999  Why would this film be so good, but only gross...      1            727
#
# [40000 rows x 3 columns]

# %%
# The longest:

df.sort_values(by='review_length',ascending=False)
# Out:
#                                                   review  label  review_length
# 6378   Match 1: Tag Team Table Match Bubba Ray and Sp...      1          13704
# 34167  There's a sign on The Lost Highway that says:<...      1          12988
# 32922  Back in the mid/late 80s, an OAV anime by titl...      1          12129
# 27424  **Attention Spoilers**<br /><br />First of all...      1          10363
# 5878   Titanic directed by James Cameron presents a f...      1          10321
# ...                                                  ...    ...            ...
# 28914  I wouldn't rent this one even on dollar rental...      0             53
# 36009  Primary plot!Primary direction!Poor interpreta...      0             51
# 32386  I hope this group of film-makers never re-unites.      0             49
# 15400          What a script, what a story, what a mess!      0             41
# 26067                   Read the book, forget the movie!      0             32
#
# [40000 rows x 3 columns]

# %%
# The shortest:

df.sort_values(by=['review_length'])
# Out:
#                                                   review  label  review_length
# 26067                   Read the book, forget the movie!      0             32
# 15400          What a script, what a story, what a mess!      0             41
# 32386  I hope this group of film-makers never re-unites.      0             49
# 36009  Primary plot!Primary direction!Poor interpreta...      0             51
# 28914  I wouldn't rent this one even on dollar rental...      0             53
# ...                                                  ...    ...            ...
# 5878   Titanic directed by James Cameron presents a f...      1          10321
# 27424  **Attention Spoilers**<br /><br />First of all...      1          10363
# 32922  Back in the mid/late 80s, an OAV anime by titl...      1          12129
# 34167  There's a sign on The Lost Highway that says:<...      1          12988
# 6378   Match 1: Tag Team Table Match Bubba Ray and Sp...      1          13704
#
# [40000 rows x 3 columns]

# %% [markdown]
# ## Text data cleaning

# %%
stop_words = list(stopwords.words('English'))

def preprocess(review):
   
    result = []
    for token in gensim.utils.simple_preprocess(review):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3 and token not in stop_words:
            result.append(token)
            
    return result

# %%
# apply the function to the dataset:

df['clean_review'] = df['review'].apply(preprocess)

# %%
# join the words into a string
df['clean_review_joined'] = df['clean_review'].apply(lambda x: " ".join(x))

# %%
df
# Out:
#                                                   review  label  \
# 0      I grew up (b. 1965) watching and loving the Th...      0
# 1      When I put this movie in my DVD player, and sa...      0
# 2      Why do people who do not know what a particula...      0
# 3      Even though I have great interest in Biblical ...      0
# 4      Im a die hard Dads Army fan and nothing will e...      1
# ...                                                  ...    ...
# 39995  "Western Union" is something of a forgotten cl...      1
# 39996  This movie is an incredible piece of work. It ...      1
# 39997  My wife and I watched this movie because we pl...      0
# 39998  When I first watched Flatliners, I was amazed....      1
# 39999  Why would this film be so good, but only gross...      1
#
#        review_length                                       clean_review  \
# 0                874  [grew, watching, loving, thunderbirds, mates, ...
# 1               1811  [movie, player, coke, chips, expectations, hop...
# 2                983  [people, know, particular, time, past, like, f...
# 3                351  [great, biblical, movies, bored, death, minute...
# 4                983  [hard, dads, army, change, tapes, audiobooks, ...
# ...              ...                                                ...
# 39995           3111  [western, union, forgotten, classic, western, ...
# 39996            291  [movie, incredible, piece, work, explores, noo...
# 39997           1092  [wife, watched, movie, plan, visit, sicily, st...
# 39998           1045  [watched, flatliners, amazed, necessary, featu...
# 39999            727  [film, good, gross, estimated, award, nominati...
#
#                                      clean_review_joined
# 0      grew watching loving thunderbirds mates school...
# 1      movie player coke chips expectations hoping mo...
# 2      people know particular time past like feel nee...
# 3      great biblical movies bored death minute movie...
# 4      hard dads army change tapes audiobooks time wa...
# ...                                                  ...
# 39995  western union forgotten classic western reason...
# 39996  movie incredible piece work explores nook cran...
# 39997  wife watched movie plan visit sicily stromboli...
# 39998  watched flatliners amazed necessary features g...
# 39999  film good gross estimated award nominations jo...
#
# [40000 rows x 5 columns]

# %% [markdown]
# ## WordCloud visualization

# %%
text=' '.join(df['clean_review_joined'])


my_cloud=WordCloud(background_color='white',stopwords=stop_words).generate(text)
plt.imshow(my_cloud, interpolation='bilinear') 
plt.axis("off")
plt.show()

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# Returns results as a named tuple of the form: Sentiment(polarity, subjectivity)

# %%
df['sentiment'] = df.clean_review_joined.apply(lambda text: TextBlob(text).sentiment)
df
# Out:
#                                                   review  label  \
# 0      I grew up (b. 1965) watching and loving the Th...      0
# 1      When I put this movie in my DVD player, and sa...      0
# 2      Why do people who do not know what a particula...      0
# 3      Even though I have great interest in Biblical ...      0
# 4      Im a die hard Dads Army fan and nothing will e...      1
# ...                                                  ...    ...
# 39995  "Western Union" is something of a forgotten cl...      1
# 39996  This movie is an incredible piece of work. It ...      1
# 39997  My wife and I watched this movie because we pl...      0
# 39998  When I first watched Flatliners, I was amazed....      1
# 39999  Why would this film be so good, but only gross...      1
#
#        review_length                                       clean_review  \
# 0                874  [grew, watching, loving, thunderbirds, mates, ...
# 1               1811  [movie, player, coke, chips, expectations, hop...
# 2                983  [people, know, particular, time, past, like, f...
# 3                351  [great, biblical, movies, bored, death, minute...
# 4                983  [hard, dads, army, change, tapes, audiobooks, ...
# ...              ...                                                ...
# 39995           3111  [western, union, forgotten, classic, western, ...
# 39996            291  [movie, incredible, piece, work, explores, noo...
# 39997           1092  [wife, watched, movie, plan, visit, sicily, st...
# 39998           1045  [watched, flatliners, amazed, necessary, featu...
# 39999            727  [film, good, gross, estimated, award, nominati...
#
#                                      clean_review_joined  \
# 0      grew watching loving thunderbirds mates school...
# 1      movie player coke chips expectations hoping mo...
# 2      people know particular time past like feel nee...
# 3      great biblical movies bored death minute movie...
# 4      hard dads army change tapes audiobooks time wa...
# ...                                                  ...
# 39995  western union forgotten classic western reason...
# 39996  movie incredible piece work explores nook cran...
# 39997  wife watched movie plan visit sicily stromboli...
# 39998  watched flatliners amazed necessary features g...
# 39999  film good gross estimated award nominations jo...
#
#                                          sentiment
# 0        (0.16350000000000003, 0.6340000000000001)
# 1        (0.25710034013605443, 0.5239370748299319)
# 2      (-0.13041666666666668, 0.39988095238095234)
# 3                                    (-0.15, 0.63)
# 4        (0.13911564625850342, 0.6259353741496599)
# ...                                            ...
# 39995    (0.09689849624060146, 0.3939640768588138)
# 39996   (0.23055555555555554, 0.35277777777777786)
# 39997    (0.05178571428571428, 0.6050000000000001)
# 39998    (0.35871212121212115, 0.5772186147186147)
# 39999                  (0.2998863636363637, 0.565)
#
# [40000 rows x 6 columns]

# %%
# We want to split 'sentiment' column into two different columns: 'polarity' and 'subjectivity':

df['sentiment'][0][0]
df['polarity'] = df['sentiment'].apply(lambda x: x[0])
df['subjectivity'] = df['sentiment'].apply(lambda x: x[1])

# %%
df
# Out:
#                                                   review  label  \
# 0      I grew up (b. 1965) watching and loving the Th...      0
# 1      When I put this movie in my DVD player, and sa...      0
# 2      Why do people who do not know what a particula...      0
# 3      Even though I have great interest in Biblical ...      0
# 4      Im a die hard Dads Army fan and nothing will e...      1
# ...                                                  ...    ...
# 39995  "Western Union" is something of a forgotten cl...      1
# 39996  This movie is an incredible piece of work. It ...      1
# 39997  My wife and I watched this movie because we pl...      0
# 39998  When I first watched Flatliners, I was amazed....      1
# 39999  Why would this film be so good, but only gross...      1
#
#        review_length                                       clean_review  \
# 0                874  [grew, watching, loving, thunderbirds, mates, ...
# 1               1811  [movie, player, coke, chips, expectations, hop...
# 2                983  [people, know, particular, time, past, like, f...
# 3                351  [great, biblical, movies, bored, death, minute...
# 4                983  [hard, dads, army, change, tapes, audiobooks, ...
# ...              ...                                                ...
# 39995           3111  [western, union, forgotten, classic, western, ...
# 39996            291  [movie, incredible, piece, work, explores, noo...
# 39997           1092  [wife, watched, movie, plan, visit, sicily, st...
# 39998           1045  [watched, flatliners, amazed, necessary, featu...
# 39999            727  [film, good, gross, estimated, award, nominati...
#
#                                      clean_review_joined  \
# 0      grew watching loving thunderbirds mates school...
# 1      movie player coke chips expectations hoping mo...
# 2      people know particular time past like feel nee...
# 3      great biblical movies bored death minute movie...
# 4      hard dads army change tapes audiobooks time wa...
# ...                                                  ...
# 39995  western union forgotten classic western reason...
# 39996  movie incredible piece work explores nook cran...
# 39997  wife watched movie plan visit sicily stromboli...
# 39998  watched flatliners amazed necessary features g...
# 39999  film good gross estimated award nominations jo...
#
#                                          sentiment  polarity  subjectivity
# 0        (0.16350000000000003, 0.6340000000000001)  0.163500      0.634000
# 1        (0.25710034013605443, 0.5239370748299319)  0.257100      0.523937
# 2      (-0.13041666666666668, 0.39988095238095234) -0.130417      0.399881
# 3                                    (-0.15, 0.63) -0.150000      0.630000
# 4        (0.13911564625850342, 0.6259353741496599)  0.139116      0.625935
# ...                                            ...       ...           ...
# 39995    (0.09689849624060146, 0.3939640768588138)  0.096898      0.393964
# 39996   (0.23055555555555554, 0.35277777777777786)  0.230556      0.352778
# 39997    (0.05178571428571428, 0.6050000000000001)  0.051786      0.605000
# 39998    (0.35871212121212115, 0.5772186147186147)  0.358712      0.577219
# 39999                  (0.2998863636363637, 0.565)  0.299886      0.565000
#
# [40000 rows x 8 columns]

# %%
# We create a new column named: 'sentiment_score' based on the 'polarity' column:

conditions = [
    (df['polarity'] <0),
    (df['polarity'] ==0),
    (df['polarity'] > 0)
    ]

# create a list of the values we want to assign for each condition
values = ['negative', 'neutral', 'positive']

# create a new column and use np.select to assign values to it using our lists as arguments
df['sentiment_score'] = np.select(conditions, values)

# display updated DataFrame
df.head()
# Out:
#                                               review  label  review_length  \
# 0  I grew up (b. 1965) watching and loving the Th...      0            874
# 1  When I put this movie in my DVD player, and sa...      0           1811
# 2  Why do people who do not know what a particula...      0            983
# 3  Even though I have great interest in Biblical ...      0            351
# 4  Im a die hard Dads Army fan and nothing will e...      1            983
#
#                                         clean_review  \
# 0  [grew, watching, loving, thunderbirds, mates, ...
# 1  [movie, player, coke, chips, expectations, hop...
# 2  [people, know, particular, time, past, like, f...
# 3  [great, biblical, movies, bored, death, minute...
# 4  [hard, dads, army, change, tapes, audiobooks, ...
#
#                                  clean_review_joined  \
# 0  grew watching loving thunderbirds mates school...
# 1  movie player coke chips expectations hoping mo...
# 2  people know particular time past like feel nee...
# 3  great biblical movies bored death minute movie...
# 4  hard dads army change tapes audiobooks time wa...
#
#                                      sentiment  polarity  subjectivity  \
# 0    (0.16350000000000003, 0.6340000000000001)  0.163500      0.634000
# 1    (0.25710034013605443, 0.5239370748299319)  0.257100      0.523937
# 2  (-0.13041666666666668, 0.39988095238095234) -0.130417      0.399881
# 3                                (-0.15, 0.63) -0.150000      0.630000
# 4    (0.13911564625850342, 0.6259353741496599)  0.139116      0.625935
#
#   sentiment_score
# 0        positive
# 1        positive
# 2        negative
# 3        negative
# 4        positive

# %%
# save the dataset:

df.to_csv("movie_review_sentiment_analysis.csv")

# %%
# percentage of positive, negative and neutral values:

df['sentiment_score'].value_counts()/len(df)
# Out:
# positive    0.72975
# negative    0.26825
# neutral     0.00200
# Name: sentiment_score, dtype: float64

# %%
# Pie Chart visualization:

sentiment_score = df["sentiment_score"].value_counts()
numbers = sentiment_score.index
quantity = sentiment_score.values


custom_colors = ["darksalmon", "darkseagreen",'gold']
plt.figure(figsize=(8, 8))

plt.pie(quantity, labels=numbers, colors=custom_colors)
central_circle = plt.Circle((0, 0), 0.5, color='white')

fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=14)
plt.title("Sentiment", fontsize=20)

plt.show()
